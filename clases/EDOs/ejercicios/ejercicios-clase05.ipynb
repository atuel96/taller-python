# %% [markdown]
# # Ejercicios Clase 05. Método de Euler y Runge Kutta
#
# Cada ejercicio tiene una celda en blanco para que escriba su propio código. Puede crear celdas extras en caso de ser necesario, o simplemente por comodidad. Al momento de resolver los ejercicios utilice sus propias variables con nombres que ayuden a la comprensión del problema.
#
# ## Ejercicio 0. Visita a Números Famosos
#
# Aplique el método de Euler para obtener 2 de los famosos números de la matemática. Pruebe con distintas cantidades de puntos hasta conseguir el valor deseado redondeado a tres cifras significativas.
#
# ###     a) Número $e$
#
# Obtenga el número $e=y(1)$ donde $y(x)$ es la solución del problema de valor inicial
# $$
# dy/dx=y\text{, con  } y(0)=1
# $$

# %%
# Ejercicio 0.a

# %% [markdown]
# ### b) Núemero $\pi$
#
# el número $\pi=y(1)$ donde $y(x)$ es la solución del problema de valor inicial
#
#
# $$
# \frac{dy}{dx} = \frac{4}{1+x^2} ,  \text{   con} \ \ y(0) = 0
# $$

# %%
# Ejercicio 0.b

# %% [markdown]
# ## Ejercicio 1
#
# Suponga que en un pequeño bosque la población de ciervos $P(t)$ inicialmente es de 25 individuos y satisface la ecuación logística
# $$
# \frac{dP}{dt} = 0.0225P − 0.0003P^2
# $$
# (con $t$ en meses).
#
# Utilice el método de Euler mejorado con el fin de aproximar la solución para 10 años, primero con un tamaño de paso $h = 1$ y después con $h = 0.5$, redondeando los valores aproximados de $P$ a 3 cifras decimales, ¿qué porcentaje de la población límite de 75 ciervos se obtiene después de 5 años? ¿Después de 10 años?

# %%
# Ejercicio 1

# %% [markdown]
# ## Ejercicio 2
#
# La figura muestra un tanque esférico para almacenar agua. El tanque se llena por un agujero en la parte superior y se drena por un agujero en el fondo.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Si el radio del tanque es $r$, usted puede usar la integración para demostrar que el volumen $V$ del agua en el tanque como función de su altura $h$ está dado por
#
# $$
# V(h) = \pi r h^2 - \pi \frac{h^3}{3}
# $$
#
# El principio de Torricelli establece que el caudal del líquido por el agujero es proporcional a la raíz cuadrada de la altura $h$. Estudios posteriores de mecánica de fluidos han identificado la relación con más precisión, y el resultado es que el caudal volumétrico por el orificio está dado por
#
# $$
# q = C_d A \sqrt{2gh}
# $$
#
# donde $A$ es el área del orificio, $g$ es la aceleración debida a la gravedad y $C_d$ es un valor determinado experimentalmente que depende parcialmente del tipo de líquido. Para agua, $C_d = 0.6$ es un valor común.
# Podemos usar el principio de conservación de la masa para obtener una ecuación diferencial para la altura $h$. Aplicado a este tanque, el principio dice que la rapidez de cambio del volumen de líquido en el tanque debe ser igual al caudal de salida del tanque; es decir,
#
# $$
# \frac{dV}{dt} = -q
# $$
#
# Por la ecuación anterior, tenemos
#
# $$
# \frac{dV}{dt} = 2\pi r h\frac{dh}{dt} - \pi h^2\frac{dh}{dt} \\
# \frac{dV}{dt} = \pi h (2r - h)\frac{dh}{dt}
# $$
#
# Sustituyendo ésta y las ecuaciones anteriores, obtenemos la ecuación necesaria para $h$,
#
# $$
# \pi h (2r - h)\frac{dh}{dt} = - C_d A \sqrt{2gh}
# $$
#
# Use Python y el método de Euler para resolver esta ecuación y determinar cuánto tardará el tanque en vaciarse si la altura inicial es 9 pies. El tanque tiene un radio $r = 5\text{ pies}$, y
# tiene un orificio de 1 pulgada de diámetro en el fondo. Use $C_d = 0.6$ y $g = 32.2\text{ pies}/s^2$

# %%
# Ejercicio 2

# %% [markdown]
# ## Ejercicio 3
#
# Utilice el método de las diferencias finitas para calcular la primera derivada de la función
#
# $$y= sen(x)$$
#
# entre $0$ y $2\pi$ y su correspondiente gráfica. Luego avance con la segunda derivada de la misma función.

# %%
# Ejercicio 3
